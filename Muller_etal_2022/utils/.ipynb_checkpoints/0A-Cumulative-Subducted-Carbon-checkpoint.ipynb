# %% [markdown]
# # A - Cumulative subducted carbon
#
# Produce grids of cumulative subducted from each contribution of:
#
# - Sediment
# - Serpentinite
# - Crust
# - Lithosphere
#
# through time.
#
# The previous notebook __Subducted Carbon.ipynb__ must be run before this notebook.
#
# ### Note: To save the outputs in this notebook once, the chosen hard drive requires at least 150 GB of free storage.

# %%
from multiprocessing import Pool, cpu_count
from joblib import Parallel, delayed
import joblib
import numpy as np
import pygplates
import gplately
import gplately.grids as grids
import gplately.tools as tools
import ptt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io import shapereader as shpreader
import netCDF4
from scipy import ndimage
import pandas as pd
import glob, os
from slabdip import SlabDipper
import numpy.ma as ma
# %matplotlib inline
# plt.style.use('ggplot')

#from pygplates_helper import *

# common variables
extent_globe = [-180, 180, -90, 90]
earth_radius = 6371.0e3
earth_surface_area = 4.0*np.pi*earth_radius**2
tessellation_threshold_radians = np.radians(0.01)

# output grid resolution - should be identical to input grid resolution!
spacingX, spacingY = 0.2, 0.2
resX, resY = int(360./0.2 + 1), int(180./0.2 + 1)
lon_grid = np.arange(extent_globe[0], extent_globe[1]+spacingX, spacingX)
lat_grid = np.arange(extent_globe[2], extent_globe[3]+spacingY, spacingY)
lonq, latq = np.meshgrid(lon_grid,lat_grid)

# reconstruction time steps and spacing
min_time = 0
max_time = 1000
timestep_size = 1

# time array
# reversed (start at max_time, end at min_time)
reconstruction_times = np.arange(max_time, min_time-timestep_size, -timestep_size)




# OUTPUT SAVING TOGGLES
save_output_netcdf = True # !! important
save_output_snapshots = False

# This is to save outputs from the parallelised "carbon_subducted_and_accreted" routine
save_outputs_to_csv = True

# %% [markdown]
# ### Ensure all needed output paths are created
# Change `folder_name` to keep track of results of Notebook 03 reruns

# %%
save_cumulative_subducted_carbon = True
save_smoothed_timestep_grid = True
save_smoothed_cumulative_grid = True

# Save the sum of crust + lithosphere + serpentinite
save_mantle_cumulative_subducted_carbon = True

# %%
# Change `folder_name`: a string to name a new sub-folder for a new set of Notebook 2 outputs; 
# useful for keeping track of reruns
folder_name = "Muller22_Mar2"


# --------------- Everything below here can be kept as-is ----------------
# FOR CUMULATIVE SUBDUCTED CARBON PER TIMESTEP
output_cumulative_subducted_carbon_grid_directory = "../Outputs/{}/Notebook02/cumulative_subducted_carbon/{}/{}/"

for storage in ['Lithosphere', 'Serpentinite', 'Crust', 'Sediment', 'Mantle', 'Organic_Sediments']:
    for quantity in ['min', 'mean', 'max']:
        os.makedirs(output_cumulative_subducted_carbon_grid_directory.format(folder_name, storage, quantity), exist_ok=True)

# %% [markdown]
# Define gplately's `PlateReconstruction` and `PlotTopologies` objects.

# %%
# Use GPlately's DataServer to get a rotation model, topology features and static polygons
gdownload = gplately.download.DataServer("Muller2022", verbose=False)
rotation_model, topology_features, static_polygons = gdownload.get_plate_reconstruction_files()

model = gplately.PlateReconstruction(rotation_model, topology_features, static_polygons)

# Use GPlately's DataServer to get coastlines and continents
coastlines, continents, COBs = gdownload.get_topology_geometries()

time = max_time
gplot = gplately.PlotTopologies(model, time=time, coastlines=coastlines, continents=continents)

# %%
cell_area = tools.lat_area_function(lat_grid, lat_grid+spacingY, lon_grid.size)
cell_area = np.tile(cell_area.reshape(-1,1), lon_grid.size)

# %%
# Register colourmaps
from matplotlib.colors import LinearSegmentedColormap
import os

cmap_dir = "./ScientificColourMaps5/"

def get_immediate_subdirectories(a_dir):
    return [name for name in os.listdir(a_dir)
            if os.path.isdir(os.path.join(a_dir, name))]

subdirs = get_immediate_subdirectories(cmap_dir)

cmap_crameri = dict()
for subdir in subdirs:
    print (subdir)
    cm_data = np.loadtxt(cmap_dir+"{}/{}.txt".format(subdir, subdir))
    cmap_crameri[subdir] = LinearSegmentedColormap.from_list(subdir, cm_data)
    cmap_crameri[subdir+'_r'] = LinearSegmentedColormap.from_list(subdir+'_r', cm_data[::-1])
    plt.register_cmap(cmap=cmap_crameri[subdir])
    plt.register_cmap(cmap=cmap_crameri[subdir+'_r'])
# Out:
# acton
# bamako
# batlow
# berlin
# bilbao
# broc
# buda
# cork
# davos
# devon
# grayC
# hawaii
# imola
# lajolla
# lapaz
# lisbon
# nuuk
# oleron
# oslo
# roma
# tofino
# tokyo
# turku
# vik

# %% [markdown]
# ## Make rasters of cumulative subducted carbon
#
# ### Build the `cumulative_subducted_carbon` array
# If `save_output_netcdf` was set to `True` in Notebook `02-Subducted-Carbon.ipynb`, masked arrays of total global subducted carbon per timestep would have been saved to a netCDF4 grid. All grid nodes with no subducted carbon are given NaN entries.
#
# In the cells below, we loop through time to collect the carbon subducted for each carbon storage reservoir and quantity. At each time step, we append the current contribution to an array, `cumulative_subducted_carbon` for a given component and quantity. Every timestep we save the current cumulative subducted carbon grid to a netcdf file.
#
# To make this process faster, it is performed using parallelisation with `joblib`. The process is made more memory-friendly by partitioning the time array (and thus the parallel tasks) into groups of times.

# %%
# Define carbon quantities and components
carbon_components = ["Sediment", "Serpentinite", "Crust", "Lithosphere", "Organic_Sediments"]
quantities = ["min", "mean", "max"]

# Define path to the subducted carbon contributions per timestep
subducted_carbon_grid_filename = "../Outputs/{}/Notebook02/subducted_carbon/{}/{}/subducted_carbon_{}_{}.nc"

# %% [markdown]
# ### Function to smooth subducted carbon contribution grids with `scipy.ndimage`'s `fourier_gaussian()` filter
# ...which we access from an outsourced utility script `fft_gaussian_filter.py` in the `/utils/` directory.

# %%
if save_smoothed_timestep_grid:
    
    import sys
    sys.path.insert(0, './utils/')

    import fft_gaussian_filter as fft_gaussian_filter_script

    def gaussian_smooth_grid(data, distance_km):
   
        """ Smooth grids using a Gaussian. 
        If input grid comes with a mask, all masked values are retained. 
        """
        mask = np.isnan(data)
        smoothed_grid = fft_gaussian_filter_script.fft_gaussian_filter(data, distance_km)
        smoothed_grid[mask] = np.nan
        return smoothed_grid

# %% [markdown]
# Select a Gaussian filter width (km) and produce a save directory for all cumulative grids with this smoothing filter width.

# %%
distance_km = 300

# Define path to the cumulative subducted carbon grid we will make in this cell
output_cumulative_subducted_carbon_filename = "../Outputs/{}/Notebook02/cumulative_subducted_carbon/{}/{}/cumulative_subducted_carbon_{}_{}.nc"
output_smooth_cumulative_subducted_carbon_grid_directory = "../Outputs/{}/Notebook02/smoothed_cumulative_subducted_carbon/{}km/{}/{}/"
output_smooth_cumulative_subducted_carbon_filename = "../Outputs/{}/Notebook02/smoothed_cumulative_subducted_carbon/{}km/{}/{}/cumulative_subducted_carbon_{}_{}.nc"

for storage in ['Mantle', 'Sediment', 'Crust', "Organic_Sediments"]:
    for quantity in ['min', 'mean', 'max']:
        os.makedirs(output_smooth_cumulative_subducted_carbon_grid_directory.format(folder_name, distance_km, storage, quantity), exist_ok=True)
        
        
output_smoothed_subducted_carbon_grid_directory = "../Outputs/{}/Notebook03/smoothed_subducted_carbon/{}km/{}/{}/"
smoothed_subducted_carbon_grid_filename = "../Outputs/{}/Notebook03/smoothed_subducted_carbon/{}km/{}/{}/subducted_carbon_{}_{}.nc"
for storage in ['Lithosphere', 'Serpentinite', 'Crust', 'Sediment', 'Organic_Sediments']:
    for quantity in ['min', 'mean', 'max']:
        os.makedirs(output_smoothed_subducted_carbon_grid_directory.format(folder_name, distance_km, storage, quantity), exist_ok=True)

# %% [markdown]
# ### Accumulate grids in parallel, save to netCDF in a single core

# %%
def accumulate_subducted_carbon(component, reconstruction_time, distance_km=300):
    
    # Store cumulative subducted carbon from the grids in a numpy array
    subducted_carbon_components = np.zeros((3, resY, resX))
    smoothed_subducted_carbon_components = np.zeros((3, resY, resX))

    for i, quantity in enumerate(quantities):

        subducted_carbon_filename = subducted_carbon_grid_filename.format(
            folder_name, component, quantity, component.lower(), reconstruction_time
        )

        # Read the masked subducted carbon contribution array for the current time
        current_time_grid = grids.read_netcdf_grid(subducted_carbon_filename)

        # Get the data array, and fill all NaNs with 0s.
        current_time_grid = np.nan_to_num(current_time_grid.data)
        
        current_time_grid_filled = grids.fill_raster(current_time_grid)
        subducted_carbon_components[i] = current_time_grid_filled

        # If the user wants the smoothed piecewise grids to be returned,
        if save_smoothed_timestep_grid:

            
            # Define the filename for saving the smoothed grids
            smoothed_filename = smoothed_subducted_carbon_grid_filename.format(
                    folder_name, distance_km, component, quantity, component.lower(), reconstruction_time
            )
            # Smooth the grids
            smoothed_current_time_grid = gaussian_smooth_grid(
                current_time_grid_filled,
                
                distance_km=distance_km
            )
            # Read in the smoothed grid, fill the raster, and return
            smoothed_current_time_grid_filled = grids.fill_raster(smoothed_current_time_grid)
            smoothed_subducted_carbon_components[i] += smoothed_current_time_grid_filled
            
            # Create a mask for the interpolated grid - all values with 0s need to have an equivalent
            # mask value of NaN. 
            smoothed_current_time_grid_filled_masked = ma.masked_array(smoothed_current_time_grid_filled)
            smoothed_current_time_grid_filled_masked = ma.masked_values(smoothed_current_time_grid_filled_masked, 0.0)
            smoothed_current_time_grid_filled_masked.fill_value = np.nan
            
            current_subducted_carbon_smoothed = np.ma.array(
                    smoothed_subducted_carbon_components[i],
                    mask = smoothed_current_time_grid_filled_masked.mask,
                    fill_value=np.nan
                )
            
            grids.write_netcdf_grid(
                smoothed_filename,
                current_subducted_carbon_smoothed
            )

    if save_smoothed_timestep_grid:
        return subducted_carbon_components, reconstruction_time, smoothed_current_time_grid_filled, smoothed_filename
    else:
        return subducted_carbon_components, reconstruction_time

        
def accumulate_smoothed_mantle_grids(reconstruction_time, distance_km=300):
    
    # Store cumulative subducted carbon from the grids in a numpy array
    smoothed_subducted_carbon_components = np.zeros((3, resY, resX))

    for i, quantity in enumerate(quantities):
        for c, component in enumerate(["Lithosphere", "Crust", "Serpentinite"]):

            subducted_carbon_filename = smoothed_subducted_carbon_grid_filename.format(
                folder_name, distance_km, component, quantity, component.lower(), reconstruction_time
            )

            current_time_grid = grids.read_netcdf_grid(subducted_carbon_filename)
            # Get the data array, and fill all NaNs with 0s.
            current_time_grid = np.nan_to_num(current_time_grid.data)
            current_time_grid_filled = grids.fill_raster(current_time_grid)

            # For the current time, we have a 3 by resY by resX grid. Each dimension in
            # axis 0 is the sum of all crust, serpentinite and lithosphere in the 
            # min, mean and max (respectively)
            smoothed_subducted_carbon_components[i] += current_time_grid_filled

    return smoothed_subducted_carbon_components


def accumulate_reservoir_grids(reconstruction_time, component, distance_km=300):
    
    # Store cumulative subducted carbon from the grids in a numpy array
    smoothed_subducted_carbon_components = np.zeros((3, resY, resX))

    for i, quantity in enumerate(quantities):

        subducted_carbon_filename = smoothed_subducted_carbon_grid_filename.format(
            folder_name, distance_km, component, quantity, component.lower(), reconstruction_time
        )

        current_time_grid = grids.read_netcdf_grid(subducted_carbon_filename)
        # Get the data array, and fill all NaNs with 0s.
        current_time_grid = np.nan_to_num(current_time_grid.data)
        current_time_grid_filled = grids.fill_raster(current_time_grid)

        # For the current time, we have a 3 by resY by resX grid. Each dimension in
        # axis 0 is the current reservoir subducted carbon grid in min, mean and max (respectively)
        smoothed_subducted_carbon_components[i] += current_time_grid_filled

    return smoothed_subducted_carbon_components

# %% [markdown]
# ## Accumulate grids in parallel...
#
# This cell can get memory-intensive. We can relieve memory pressure by setting `time_splitter_integer` to a smaller value. It can be 0, or negative. The smaller the value, the smaller the chunks of timesteps used for accumulation.

# %%
time_splitter_integer = -5

# %%
with Parallel(n_jobs=-3, verbose=1) as parallel:
    cumulative_subducted_carbon = np.zeros((len(carbon_components), 3, resY, resX))
    smoothed_cumulative_subducted_carbon = np.zeros((len(carbon_components), 3, resY, resX))
    total_smoothed_cumulative_mantle = np.zeros((3, resY, resX))
    
    # Split the time array into groups of timesteps
    split_times = np.array_split(reconstruction_times, cpu_count() - time_splitter_integer)
    
    # Start counting current time from min_time
    curr_time = min_time
    
    # Loop through each time array. get a group of subducted carbon contributions
    for times in split_times:
        for c, component in enumerate(carbon_components):
            
            if component == "Sediment" and times[-1] > 170.:
                continue
                
            if component == "Organic_Sediments" and times[-1] > 540.:
                continue
            
            print("Accumulating {} grids from {} to {}Ma...".format(component, times[0], times[-1]))
            
            # Accumulate raw carbon grids, and simultaneously smooth the individual contributions.
            results = parallel(delayed(accumulate_subducted_carbon)(
                component, 
                time,
                distance_km=distance_km
            ) 
               for time in times
            )

            results = np.array(results, dtype=object)

            carbon_subducted = results[:,0]
            curr_times = results[:,1]
            
            if save_smoothed_timestep_grid:
                print("Smoothed {} grids from {} to {}Ma, saving grids now...".format(component, times[0], times[-1]))
                smoothed_carbon_subducted = results[:,2]

            # For each time index and result in the current result array,
            for t, subducted_carbon_components in enumerate(carbon_subducted):
                
                # We have one array per timestep with 3 entries for min, mean and max. 
                # print(component, t, len(subducted_carbon_components)) 
                if save_cumulative_subducted_carbon:
                    cumulative_subducted_carbon[c] += subducted_carbon_components 
                
                # Repeat for the smoothed subducted carbon piecewise grids if saving smoothed grids. 
                if save_smoothed_cumulative_grid:
                    smoothed_cumulative_subducted_carbon[c] += smoothed_carbon_subducted[t]
                    
                
                for q, quantity in enumerate(quantities):
                    
                    # Save the raw cumulative subducted carbon grid. 
                    if save_cumulative_subducted_carbon:
                        
                        # Make the mask
                        cumulative_subducted_carbon_curr = ma.masked_array(cumulative_subducted_carbon[c,q])
                        cumulative_subducted_carbon_curr = ma.masked_values(cumulative_subducted_carbon_curr, 0.0)
                        cumulative_subducted_carbon_curr.fill_value = np.nan

                        current_cumulative_subducted_carbon = np.ma.array(
                                cumulative_subducted_carbon[c,q],
                                mask = cumulative_subducted_carbon_curr.mask,
                                fill_value=np.nan
                            )
                        
                        gplately.grids.write_netcdf_grid(
                            output_cumulative_subducted_carbon_filename.format(
                                folder_name, 
                                component, 
                                quantity, 
                                component.lower(), 
                                curr_times[t]
                            ), 
                            current_cumulative_subducted_carbon
                        )
                        
                    # Save the smoothed cumulative subducted carbon grid if sediment.
                    if component == "Sediment" or component == "Organic_Sediments":
                        if save_smoothed_cumulative_grid: 
                            
                            # Make the mask
                            cumulative_sediment = ma.masked_array(smoothed_cumulative_subducted_carbon[c,q])
                            cumulative_sediment = ma.masked_values(cumulative_sediment, 0.0)
                            cumulative_sediment.fill_value = np.nan

                            current_cumulative_subducted_sediment = np.ma.array(
                                    smoothed_cumulative_subducted_carbon[c,q],
                                    mask = cumulative_sediment.mask,
                                    fill_value=np.nan
                                )
                        
                            gplately.grids.write_netcdf_grid(
                                output_smooth_cumulative_subducted_carbon_filename.format(
                                    folder_name, 
                                    distance_km,
                                    component, 
                                    quantity, 
                                    component.lower(), 
                                    curr_times[t]
                                ), 
                                current_cumulative_subducted_sediment
                            )
                            
        if save_mantle_cumulative_subducted_carbon:

            mantle_results = parallel(delayed(accumulate_smoothed_mantle_grids)(time, distance_km) for time in times)
            mantle_results_arr = np.array(mantle_results, dtype=object)
            mantle_cumulative_results = mantle_results_arr[:,0]
            
            print("Saving mantle grids (lithosphere + crust + serpentinite) from {} to {}Ma...".format(times[0], times[-1]))
            
            for t, curr_time_mantle_carbon in enumerate(mantle_cumulative_results):
                
                curr_time_mantle_carbon = curr_time_mantle_carbon.astype(dtype=float)
                total_smoothed_cumulative_mantle += curr_time_mantle_carbon
                
                for q, quantity in enumerate(quantities):
                    
                    current_mantle = total_smoothed_cumulative_mantle[q,:]
                    current_mantle_filled = grids.fill_raster(current_mantle)

                    # Save the smoothed cumulative subducted carbon grid. 
                    gplately.grids.write_netcdf_grid(
                        output_smooth_cumulative_subducted_carbon_filename.format(
                            folder_name, 
                            distance_km,
                            "Mantle", 
                            quantity, 
                            "Mantle".lower(), 
                            times[t]
                        ), 
                        current_mantle_filled
                    )
# Out:
# Accumulating Serpentinite grids from 1000 to 934Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   22.9s finished
# Smoothed Serpentinite grids from 1000 to 934Ma, saving grids now...
# Accumulating Crust grids from 1000 to 934Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Crust grids from 1000 to 934Ma, saving grids now...
# Accumulating Lithosphere grids from 1000 to 934Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Lithosphere grids from 1000 to 934Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   14.6s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 1000 to 934Ma...
# Accumulating Serpentinite grids from 933 to 867Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Serpentinite grids from 933 to 867Ma, saving grids now...
# Accumulating Crust grids from 933 to 867Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Crust grids from 933 to 867Ma, saving grids now...
# Accumulating Lithosphere grids from 933 to 867Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.5s finished
# Smoothed Lithosphere grids from 933 to 867Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   16.6s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 933 to 867Ma...
# Accumulating Serpentinite grids from 866 to 800Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.0s finished
# Smoothed Serpentinite grids from 866 to 800Ma, saving grids now...
# Accumulating Crust grids from 866 to 800Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.9s finished
# Smoothed Crust grids from 866 to 800Ma, saving grids now...
# Accumulating Lithosphere grids from 866 to 800Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.1s finished
# Smoothed Lithosphere grids from 866 to 800Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   14.8s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 866 to 800Ma...
# Accumulating Serpentinite grids from 799 to 733Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.6s finished
# Smoothed Serpentinite grids from 799 to 733Ma, saving grids now...
# Accumulating Crust grids from 799 to 733Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.5s finished
# Smoothed Crust grids from 799 to 733Ma, saving grids now...
# Accumulating Lithosphere grids from 799 to 733Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   19.9s finished
# Smoothed Lithosphere grids from 799 to 733Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   14.3s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 799 to 733Ma...
# Accumulating Serpentinite grids from 732 to 666Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.5s finished
# Smoothed Serpentinite grids from 732 to 666Ma, saving grids now...
# Accumulating Crust grids from 732 to 666Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Crust grids from 732 to 666Ma, saving grids now...
# Accumulating Lithosphere grids from 732 to 666Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Lithosphere grids from 732 to 666Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   13.0s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 732 to 666Ma...
# Accumulating Serpentinite grids from 665 to 599Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.0s finished
# Smoothed Serpentinite grids from 665 to 599Ma, saving grids now...
# Accumulating Crust grids from 665 to 599Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.6s finished
# Smoothed Crust grids from 665 to 599Ma, saving grids now...
# Accumulating Lithosphere grids from 665 to 599Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Lithosphere grids from 665 to 599Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   13.6s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 665 to 599Ma...
# Accumulating Serpentinite grids from 598 to 532Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.2s finished
# Smoothed Serpentinite grids from 598 to 532Ma, saving grids now...
# Accumulating Crust grids from 598 to 532Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.6s finished
# Smoothed Crust grids from 598 to 532Ma, saving grids now...
# Accumulating Lithosphere grids from 598 to 532Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Lithosphere grids from 598 to 532Ma, saving grids now...
# Accumulating Organic_Sediments grids from 598 to 532Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   19.9s finished
# /Users/laurenilano/opt/miniconda3/envs/januarytwo/lib/python3.9/site-packages/gplately/grids.py:310: UserWarning: Warning: converting a masked element to nan.
# Smoothed Organic_Sediments grids from 598 to 532Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   14.0s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 598 to 532Ma...
# Accumulating Serpentinite grids from 531 to 465Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.8s finished
# Smoothed Serpentinite grids from 531 to 465Ma, saving grids now...
# Accumulating Crust grids from 531 to 465Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.5s finished
# Smoothed Crust grids from 531 to 465Ma, saving grids now...
# Accumulating Lithosphere grids from 531 to 465Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.5s finished
# Smoothed Lithosphere grids from 531 to 465Ma, saving grids now...
# Accumulating Organic_Sediments grids from 531 to 465Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Organic_Sediments grids from 531 to 465Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   16.5s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 531 to 465Ma...
# Accumulating Serpentinite grids from 464 to 398Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.1s finished
# Smoothed Serpentinite grids from 464 to 398Ma, saving grids now...
# Accumulating Crust grids from 464 to 398Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.7s finished
# Smoothed Crust grids from 464 to 398Ma, saving grids now...
# Accumulating Lithosphere grids from 464 to 398Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.3s finished
# Smoothed Lithosphere grids from 464 to 398Ma, saving grids now...
# Accumulating Organic_Sediments grids from 464 to 398Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Organic_Sediments grids from 464 to 398Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   15.8s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 464 to 398Ma...
# Accumulating Serpentinite grids from 397 to 331Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.1s finished
# Smoothed Serpentinite grids from 397 to 331Ma, saving grids now...
# Accumulating Crust grids from 397 to 331Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.0s finished
# Smoothed Crust grids from 397 to 331Ma, saving grids now...
# Accumulating Lithosphere grids from 397 to 331Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Lithosphere grids from 397 to 331Ma, saving grids now...
# Accumulating Organic_Sediments grids from 397 to 331Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.4s finished
# Smoothed Organic_Sediments grids from 397 to 331Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   15.3s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 397 to 331Ma...
# Accumulating Serpentinite grids from 330 to 264Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.3s finished
# Smoothed Serpentinite grids from 330 to 264Ma, saving grids now...
# Accumulating Crust grids from 330 to 264Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.1s finished
# Smoothed Crust grids from 330 to 264Ma, saving grids now...
# Accumulating Lithosphere grids from 330 to 264Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   21.6s finished
# Smoothed Lithosphere grids from 330 to 264Ma, saving grids now...
# Accumulating Organic_Sediments grids from 330 to 264Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   20.1s finished
# Smoothed Organic_Sediments grids from 330 to 264Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:   17.3s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 330 to 264Ma...
# Accumulating Serpentinite grids from 263 to 198Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.8s finished
# Smoothed Serpentinite grids from 263 to 198Ma, saving grids now...
# Accumulating Crust grids from 263 to 198Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.1s finished
# Smoothed Crust grids from 263 to 198Ma, saving grids now...
# Accumulating Lithosphere grids from 263 to 198Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.4s finished
# Smoothed Lithosphere grids from 263 to 198Ma, saving grids now...
# Accumulating Organic_Sediments grids from 263 to 198Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.2s finished
# Smoothed Organic_Sediments grids from 263 to 198Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   17.1s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 263 to 198Ma...
# Accumulating Sediment grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.2s finished
# Smoothed Sediment grids from 197 to 132Ma, saving grids now...
# Accumulating Serpentinite grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.0s finished
# Smoothed Serpentinite grids from 197 to 132Ma, saving grids now...
# Accumulating Crust grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.7s finished
# Smoothed Crust grids from 197 to 132Ma, saving grids now...
# Accumulating Lithosphere grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.2s finished
# Smoothed Lithosphere grids from 197 to 132Ma, saving grids now...
# Accumulating Organic_Sediments grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.4s finished
# Smoothed Organic_Sediments grids from 197 to 132Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   16.2s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 197 to 132Ma...
# Accumulating Sediment grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.9s finished
# Smoothed Sediment grids from 131 to 66Ma, saving grids now...
# Accumulating Serpentinite grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.6s finished
# Smoothed Serpentinite grids from 131 to 66Ma, saving grids now...
# Accumulating Crust grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.2s finished
# Smoothed Crust grids from 131 to 66Ma, saving grids now...
# Accumulating Lithosphere grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.2s finished
# Smoothed Lithosphere grids from 131 to 66Ma, saving grids now...
# Accumulating Organic_Sediments grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.1s finished
# Smoothed Organic_Sediments grids from 131 to 66Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   16.7s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 131 to 66Ma...
# Accumulating Sediment grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.9s finished
# Smoothed Sediment grids from 65 to 0Ma, saving grids now...
# Accumulating Serpentinite grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.1s finished
# Smoothed Serpentinite grids from 65 to 0Ma, saving grids now...
# Accumulating Crust grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   21.3s finished
# Smoothed Crust grids from 65 to 0Ma, saving grids now...
# Accumulating Lithosphere grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.7s finished
# Smoothed Lithosphere grids from 65 to 0Ma, saving grids now...
# Accumulating Organic_Sediments grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   20.8s finished
# Smoothed Organic_Sediments grids from 65 to 0Ma, saving grids now...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:   14.4s finished
# Saving mantle grids (lithosphere + crust + serpentinite) from 65 to 0Ma...

# %% [markdown]
# As an aside, also accumulate crustal carbon - individual contributions would have already been smoothed.

# %%
total_smoothed_cumulative_crust = accumulate_reservoir_grids(436, "Crust", 300)

for q, quantity in enumerate(quantities):
    current_crust = total_smoothed_cumulative_crust[q,:]
    current_crust_filled = grids.fill_raster(current_crust)

    # Save the smoothed cumulative subducted carbon grid. 
    gplately.grids.write_netcdf_grid(
        output_smooth_cumulative_subducted_carbon_filename.format(
            folder_name, 
            distance_km,
            "Crust", 
            quantity, 
            "Crust".lower(), 
            436
        ), 
        current_crust_filled
    )

# %%
component = "Crust"

with Parallel(n_jobs=-3, verbose=1) as parallel:
    
    total_smoothed_cumulative_crust = np.zeros((3, resY, resX))

    # Split the time array into groups of timesteps
    split_times = np.array_split(reconstruction_times, cpu_count() - time_splitter_integer)
    
    # Start counting current time from min_time
    curr_time = min_time
    
    # Loop through each time array. get a group of subducted carbon contributions
    for times in split_times:
        
        print("Accumulating smoothed crust grids from {} to {}Ma...".format(times[0], times[-1]))

        crust_results = parallel(delayed(accumulate_reservoir_grids)(time, component, distance_km) for time in times)
        crust_results_arr = np.array(crust_results, dtype=object)
        crust_cumulative_results = crust_results_arr[:,0]

        print("Done! Saving cumulative smoothed crust grids from {} to {}Ma...".format(times[0], times[-1]))

        for t, curr_time_crust_carbon in enumerate(crust_cumulative_results):

            curr_time_crust_carbon = curr_time_crust_carbon.astype(dtype=float)
            total_smoothed_cumulative_crust += curr_time_crust_carbon

            for q, quantity in enumerate(quantities):

                current_crust = total_smoothed_cumulative_crust[q,:]
                current_crust_filled = grids.fill_raster(current_crust)

                # Save the smoothed cumulative subducted carbon grid. 
                gplately.grids.write_netcdf_grid(
                    output_smooth_cumulative_subducted_carbon_filename.format(
                        folder_name, 
                        distance_km,
                        "Crust", 
                        quantity, 
                        "Crust".lower(), 
                        times[t]
                    ), 
                    current_crust_filled
                )
# Out:
# Accumulating smoothed crust grids from 1000 to 934Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    5.7s finished
# Done! Saving cumulative smoothed crust grids from 1000 to 934Ma...
# Accumulating smoothed crust grids from 933 to 867Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.2s finished
# Done! Saving cumulative smoothed crust grids from 933 to 867Ma...
# Accumulating smoothed crust grids from 866 to 800Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.7s finished
# Done! Saving cumulative smoothed crust grids from 866 to 800Ma...
# Accumulating smoothed crust grids from 799 to 733Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.3s finished
# Done! Saving cumulative smoothed crust grids from 799 to 733Ma...
# Accumulating smoothed crust grids from 732 to 666Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.4s finished
# Done! Saving cumulative smoothed crust grids from 732 to 666Ma...
# Accumulating smoothed crust grids from 665 to 599Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.3s finished
# Done! Saving cumulative smoothed crust grids from 665 to 599Ma...
# Accumulating smoothed crust grids from 598 to 532Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.6s finished
# Done! Saving cumulative smoothed crust grids from 598 to 532Ma...
# Accumulating smoothed crust grids from 531 to 465Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.6s finished
# Done! Saving cumulative smoothed crust grids from 531 to 465Ma...
# Accumulating smoothed crust grids from 464 to 398Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.9s finished
# Done! Saving cumulative smoothed crust grids from 464 to 398Ma...
# Accumulating smoothed crust grids from 397 to 331Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    6.6s finished
# Done! Saving cumulative smoothed crust grids from 397 to 331Ma...
# Accumulating smoothed crust grids from 330 to 264Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-3)]: Done  67 out of  67 | elapsed:    7.0s finished
# Done! Saving cumulative smoothed crust grids from 330 to 264Ma...
# Accumulating smoothed crust grids from 263 to 198Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:    6.5s finished
# Done! Saving cumulative smoothed crust grids from 263 to 198Ma...
# Accumulating smoothed crust grids from 197 to 132Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:    6.4s finished
# Done! Saving cumulative smoothed crust grids from 197 to 132Ma...
# Accumulating smoothed crust grids from 131 to 66Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:    6.0s finished
# Done! Saving cumulative smoothed crust grids from 131 to 66Ma...
# Accumulating smoothed crust grids from 65 to 0Ma...
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  34 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-3)]: Done  66 out of  66 | elapsed:    6.5s finished
# Done! Saving cumulative smoothed crust grids from 65 to 0Ma...

# %% [markdown]
# ### Plotting a sample smoothed Mantle grid

# %%
quantity = "mean"
reconstruction_time = 0
sample_grid = gplately.Raster(

    output_smooth_cumulative_subducted_carbon_filename.format(
        folder_name, 
        300,
        "Mantle", 
        quantity, 
        "Mantle".lower(), 
        reconstruction_time
    )
    
)

import copy 

proj = ccrs.Mollweide()
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111, projection=proj)
ax.set_global()

ax.imshow(np.array([[0.9,0.9],[0.9,0.9]]), extent=[-180,180,-180,180], cmap='gray', vmin=0, vmax=1,
          transform=ccrs.PlateCarree(), zorder=0)

data = sample_grid.data*1e6

lognorm_cmap = copy.copy(matplotlib.cm.get_cmap('turbo'))
lognorm_cmap.set_under(color='w', alpha=0)
im = ax.imshow(data, extent=extent_globe, origin='lower', cmap=lognorm_cmap, norm=mcolors.LogNorm(vmin=1e1, vmax=1e4), 
               transform=ccrs.PlateCarree(), interpolation='nearest')

gplot.time = reconstruction_time
# add_continents(ax,  facecolor='0.7', zorder=0)
gplot.plot_coastlines(ax, color='w', alpha=0.25, zorder=2)
gplot.plot_ridges_and_transforms(ax, color='DarkRed', linewidth=1.5, zorder=2)
# add_quiver(ax, reconstruction_time, color='k', alpha=0.33, zorder=3)
gplot.plot_trenches(ax, color='k', zorder=2)
gplot.plot_subduction_teeth(ax, color='k', zorder=2)

# %% [markdown]
# ### Plotting a sample smoothed sediment grid

# %%
quantity = "mean"
reconstruction_time = 0
sample_grid = gplately.Raster(

    output_smooth_cumulative_subducted_carbon_filename.format(
        folder_name, 
        300,
        "Sediment", 
        quantity, 
        "Sediment".lower(), 
        reconstruction_time
    )
    
)

import copy 

proj = ccrs.Mollweide()
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111, projection=proj)
ax.set_global()

ax.imshow(np.array([[0.9,0.9],[0.9,0.9]]), extent=[-180,180,-180,180], cmap='gray', vmin=0, vmax=1,
          transform=ccrs.PlateCarree(), zorder=0)

data = sample_grid.data*1e6

lognorm_cmap = copy.copy(matplotlib.cm.get_cmap('turbo'))
lognorm_cmap.set_under(color='w', alpha=0)
im = ax.imshow(data, extent=extent_globe, origin='lower', cmap=lognorm_cmap, norm=mcolors.LogNorm(vmin=1e1, vmax=1e3), 
               transform=ccrs.PlateCarree(), interpolation='nearest')

gplot.time = reconstruction_time
# add_continents(ax,  facecolor='0.7', zorder=0)
gplot.plot_coastlines(ax, color='w', alpha=0.25, zorder=2)
gplot.plot_ridges_and_transforms(ax, color='DarkRed', linewidth=1.5, zorder=2)
# add_quiver(ax, reconstruction_time, color='k', alpha=0.33, zorder=3)
gplot.plot_trenches(ax, color='k', zorder=2)
gplot.plot_subduction_teeth(ax, color='k', zorder=2)

# %% [markdown]
# ### Plotting a sample smoothed crustal carbon grid

# %%
quantity = "mean"
reconstruction_time = 0
sample_grid = gplately.Raster(

    output_smooth_cumulative_subducted_carbon_filename.format(
        folder_name, 
        300,
        "Crust", 
        quantity, 
        "Crust".lower(), 
        reconstruction_time
    )
    
)

import copy 

proj = ccrs.Mollweide()
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111, projection=proj)
ax.set_global()

ax.imshow(np.array([[0.9,0.9],[0.9,0.9]]), extent=[-180,180,-180,180], cmap='gray', vmin=0, vmax=1,
          transform=ccrs.PlateCarree(), zorder=0)

data = sample_grid.data*1e6

lognorm_cmap = copy.copy(matplotlib.cm.get_cmap('turbo'))
lognorm_cmap.set_under(color='w', alpha=0)
im = ax.imshow(data, extent=extent_globe, origin='lower', cmap=lognorm_cmap, norm=mcolors.LogNorm(vmin=1e1, vmax=1e3), 
               transform=ccrs.PlateCarree(), interpolation='nearest')

gplot.time = reconstruction_time
# add_continents(ax,  facecolor='0.7', zorder=0)
gplot.plot_coastlines(ax, color='w', alpha=0.25, zorder=2)
gplot.plot_ridges_and_transforms(ax, color='DarkRed', linewidth=1.5, zorder=2)
# add_quiver(ax, reconstruction_time, color='k', alpha=0.33, zorder=3)
gplot.plot_trenches(ax, color='k', zorder=2)
gplot.plot_subduction_teeth(ax, color='k', zorder=2)

# %% [markdown]
# ### Plotting a sample smoothed organic sedimentary carbon grid

# %%
quantity = "mean"
reconstruction_time = 0
sample_grid = gplately.Raster(

    output_smooth_cumulative_subducted_carbon_filename.format(
        folder_name, 
        300,
        "Organic_Sediments", 
        quantity, 
        "Organic_Sediments".lower(), 
        reconstruction_time
    )
    
)

import copy 

proj = ccrs.Mollweide()
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111, projection=proj)
ax.set_global()

ax.imshow(np.array([[0.9,0.9],[0.9,0.9]]), extent=[-180,180,-180,180], cmap='gray', vmin=0, vmax=1,
          transform=ccrs.PlateCarree(), zorder=0)

data = sample_grid.data*1e6

lognorm_cmap = copy.copy(matplotlib.cm.get_cmap('turbo'))
lognorm_cmap.set_under(color='w', alpha=0)
im = ax.imshow(data, extent=extent_globe, origin='lower', cmap=lognorm_cmap, norm=mcolors.LogNorm(vmin=1e1, vmax=1e2), 
               transform=ccrs.PlateCarree(), interpolation='nearest')

gplot.time = reconstruction_time
# add_continents(ax,  facecolor='0.7', zorder=0)
gplot.plot_coastlines(ax, color='w', alpha=0.25, zorder=2)
gplot.plot_ridges_and_transforms(ax, color='DarkRed', linewidth=1.5, zorder=2)
# add_quiver(ax, reconstruction_time, color='k', alpha=0.33, zorder=3)
gplot.plot_trenches(ax, color='k', zorder=2)
gplot.plot_subduction_teeth(ax, color='k', zorder=2)
